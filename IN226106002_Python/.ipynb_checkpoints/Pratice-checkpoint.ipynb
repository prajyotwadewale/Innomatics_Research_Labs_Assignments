# %%
username = input("Enter username: ")
if len(username)>=6:
    print("Valid username")
else :
    print("Invalid username")
# Out:
# Enter username:  hah
# Invalid username

# %%
sales=[200,500,300,800,100]
total = 0
for amt in sales:
    total=total+amt

print("Max sales is :",max(sales))
# Out:
# Max sales is : 800

# %%
marks = {"Rajat":80,"Anita":20,"Kiran":60}
for i in marks :
    if marks[i]>50:
        print(i,":Pass")
    else:
        print(i,":Fail")
# Out:
# Rajat :Pass
# Anita :Fail
# Kiran :Pass
